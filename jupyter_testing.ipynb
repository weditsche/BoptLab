# %% [markdown]
# ### Basic tests:
# - the plan: configure the FileLoader class, that it can read .tif files, and extract relevant metadata:
# - general image shape
# - pixel size/slice intervals
# - bit depth
# - channel names
# - system imaged on
# - objective?

# %%
from src.in_out.file_loader import FileLoader
from pprint import pprint

loader = FileLoader()

# Load and print metadata for the first TIFF
tif_image_data = loader.load("resources/example_images/2C_3D_testTIF.tif")
print("----- 2C_3D_testTIF.tif Metadata -----")
pprint(tif_image_data.get_metadata())
print("--------------------------------------\n")

# Load and print metadata for the second TIFF
tif_image_data2 = loader.load("resources/example_images/Plk4_series_1_combined.tif")
print("----- Plk4_series_1_combined.tif Metadata -----")
pprint(tif_image_data2.get_metadata())
print("-----------------------------------------------\n")

# Load and print metadata for the CZI file
czi_image_data = loader.load("resources/example_images/3C_2D_testCZI.czi")
print("----- 3C_2D_testCZI.czi Metadata -----")
pprint(czi_image_data.get_metadata())
print("---------------------------------------")

czi_image_data2 = loader.load("resources/example_images/3C_3D_testCZI.czi")
print("----- 3C_3D_testCZI.czi Metadata -----")
pprint(czi_image_data2.get_metadata())
print("---------------------------------------")
# Out:
# ----- 2C_3D_testTIF.tif Metadata -----
# {'bit_depth': 16,
#  'channel_names': ['Channel 1', 'Channel 2'],
#  'pixel_size_xyz': (0.03255806290986125, 0.03255806290986125, 1.0)}
# --------------------------------------
#
# ----- Plk4_series_1_combined.tif Metadata -----
# {'bit_depth': 16,
#  'channel_names': ['Channel 1', 'Channel 2'],
#  'pixel_size_xyz': (1000.0, 1000.0, 1.0)}
# -----------------------------------------------
#
# ----- 3C_2D_testCZI.czi Metadata -----
# {'AcquisitionDate': '2023-08-09T12:34:26.4814054Z',
#  'BitCount': '16',
#  'Channels': [{'DetectionWavelength': '574-720',
#                'DetectorID': None,
#                'ExcitationWavelength': '577',
#                'Fluor': 'Alexa Fluor 568',
#                'FrameTime': None,
#                'PixelTime': None,
#                'Voltage': None},
#               {'DetectionWavelength': '420-480,495-550',
#                'DetectorID': None,
#                'ExcitationWavelength': '493',
# ...
